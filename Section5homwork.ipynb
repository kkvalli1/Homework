# %% [markdown]
#  ## 1. what does Pandas stand for?
# Pandas stands for "Panel Data," which refers to multidimensional data sets.
# The name is derived from the term "panel data" used in econometrics and statistics.

# %% [markdown]
# #### 2. What  are the 2 collections used in Pandas?
#     Series and DataFrame

# %% [markdown]
# #### 3. Name 4 things Pandas can do for us.
# ### Pandas can:
# 1. Handle missing data
# 2. Data alignment and integrated handling of missing data
# 3. Powerful, flexible group by functionality
# 4. Time series functionality
# 5. DataFrame and Series objects for data manipulation
# 6. Tools for reading and writing data between in-memory data structures and different file formats

# %% [markdown]
# #### 4. #To permanently sort a DataFrame, which keyword should one use with the `df.sort()` method?
#  The keyword to permanently sort a DataFrame using the `df.sort_values()` method is `inplace=True`.

# %% [markdown]
#  #### 5. What is a CSV?
#  A CSV (Comma-Separated Values) file is a plain text file that contains data organized in a tabular format, where each line represents a row and each value within the row is separated by a comma.

# %% [markdown]
# ### 6. When cleaning data what values do we not like in our data?
#
#  Missing values, Duplicates, Inconsistent data types, Outliers, Irrelevant data

# %%
## 7. Import NumPy, use one of the NumPy methods and create an array with a shape of (2, 3, 2). You can use the reshape method -- `.reshape()`
import numpy as np
array = np.arange(12).reshape(2, 3, 2)
print(array)

# %%
 ## 8.Use NumPy `.linspace()` to create an array with 6 linearly spaced values between 0 and 20
import numpy as np
array = np.linspace(0, 20, 6)
print(array)
# Out:
# [ 0.  4.  8. 12. 16. 20.]

# %%
##9.Make a Deep Copy of the above array
import numpy as np
original_array = np.linspace(0, 20, 6)
deep_copy_array = original_array.copy()
print(deep_copy_array)
# Out:
# [ 0.  4.  8. 12. 16. 20.]

# %%
### 10. concatenate these 3 arrays into a new array named 'newArray'...
## ```python
   ##         ([[25, 16]])
    ##        ([[11, 2], [13, 4]])
    ##        ([[7, 81], [5, 6], [11, 12]])
import numpy as np
array1 = np.array([[25, 16]])
array2 = np.array([[11, 2], [13, 4]])
array3 = np.array([[7, 81], [5, 6], [11, 12]])
newArray = np.concatenate((array1, array2, array3), axis=0)
print(newArray)

# %%
### 11.Sort 'newArray' in order into 'sortedArray'
import numpy as np
sortedArray = np.sort(newArray, axis=0)
print(sortedArray)

# %%
##12.  Unpack the array tuples from the above 'reshapedArray'  into 4 well named variables. Print the 4 variables.
import numpy as np
reshapedArray = np.arange(24).reshape(2, 3, 4)
var1, var2 = reshapedArray
print("Variable 1:\n", var1)
print("Variable 2:\n", var2)

# %%
###13. Combined and sort the following arrays into one called 'comboArray' ...

   ## ```python
   ##     one = ([10, 11, 12, 13, 14, 15, 16, 17])
     ##   two = ([20, 21, 22, 23, 24, 25, 26, 27])
       ## three = ([ 0, 1, 2, 3, 4, 5, 6, 7])
import numpy as np
one = np.array([10, 11, 12, 13, 14, 15, 16, 17])
two = np.array([20, 21, 22, 23, 24, 25, 26, 27])
three = np.array([0, 1, 2, 3, 4, 5, 6, 7])
comboArray = np.concatenate((one, two, three))
sortedComboArray = np.sort(comboArray)
print(sortedComboArray)

# %%
##14.
##Take 'comboArray' and perform the following slicing activities:
  ##  - print sec1 - the 2nd element
    ##- print sec2 - all elements from the 3rd element to the last
    ##- print sec3 - all elements from the 4th to the 14th elements
    ##- print sec4 - the last 6 elements
    ##- print sec5 - all element from #0 up to and including #15, using the negative number method, i.e. taking a section from the end.
    ##- print sec6 - from #20 every even element to the end
    ##  - print sec7 - from the last element moving forward, every 5th element.
import numpy as np
one = np.array([10, 11, 12, 13, 14, 15, 16, 17])
two = np.array([20, 21, 22, 23, 24, 25, 26, 27])
three = np.array([0, 1, 2, 3, 4, 5, 6, 7])
comboArray = np.concatenate((one, two, three))  
sec1 = comboArray[1]
sec2 = comboArray[2:]
sec3 = comboArray[3:14]
sec4 = comboArray[-6:]
sec5 = comboArray[:-9]
sec6 = comboArray[20::2]
sec7 = comboArray[::-5]
print("sec1:", sec1)
print("sec2:", sec2)
print("sec3:", sec3)
print("sec4:", sec4)
print("sec5:", sec5)
print("sec6:", sec6)
print("sec7:", sec7)

# %%
##15. Using `Series`, create a `DataFrame` that looks like this:

   ## | Ingredients | Quantity | Unit |
    ## |----|----|----|
    ## | Flour | 4 | cups |
   ## | Milk | 1 | cup |
   ## | Eggs | 2 | large |
   ## | Spam | 1 | can |

    ## Name: Dinner, dtype: object
import pandas as pd
data = {
    'Ingredients': ['Flour', 'Milk', 'Eggs', 'Spam'],
    'Quantity': [4, 1, 2, 1],
    'Unit': ['cups', 'cup', 'large', 'can']
}
df = pd.DataFrame(data)
df.name = "Dinner"
print(df)

# %%
##16. Take this data and create a DataFrame named studentData
   ## ```Python
    ##    {'Name': ['Jai', 'janusha', 'Gaurav', 'Anuj'],
      ##      'Height': [5.1, 6.2, 5.1, 5.2],
        ##    'Qualification': ['Msc', 'MA', 'Msc', 'Msc'],
          ##  'address': ['Delhi', 'Doha', 'Chennai', 'Dakhar'],
        ## 'Age': [21, 23, 24, 21],
        ##  'Pets': ['Dog', 'Bunny', 'Chinchilla', 'Parrot'],
        ## 'sport': ['Darts', 'Basketball', 'PaddleBoarding', 'Cricket']
        ##}
    ## ```
import pandas as pd
data = {
    'Name': ['Jai', 'janusha', 'Gaurav', 'Anuj'],
    'Height': [5.1, 6.2, 5.1, 5.2],
    'Qualification': ['Msc', 'MA', 'Msc', 'Msc'],
    'address': ['Delhi', 'Doha', 'Chennai', 'Dakhar'],
    'Age': [21, 23, 24, 21],
    'Pets': ['Dog', 'Bunny', 'Chinchilla', 'Parrot'],
    'sport': ['Darts', 'Basketball', 'PaddleBoarding', 'Cricket']
}
studentData = pd.DataFrame(data)        
print(studentData)

# %%
##17. Add a new column to the DataFrame with the following deserts:
    ##    ["ice cream", "Cashew Fudge", "waffels", "Carrot Halwa"]
studentData['Desert'] = ["ice cream", "Cashew Fudge", "waffels", "Carrot Halwa"]
print(studentData)

# %%
##18. Sort the 'studentData' DataFrame in Ascending order -- Sorting by column 'Name' and then "address"
sorted_studentData = studentData.sort_values(by=['Name', 'address'], ascending=True)
print(sorted_studentData)

# %%
##!9. Save this `DataFrame` here below to disc as a `.CSV` file with the name `cows_and_goats.csv`:

## python
## df = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
import pandas as pd
df = pd.DataFrame({'Cows': [12, 20], 'Goats': [22, 19]}, index=['Year 1', 'Year 2'])
df.to_csv('cows_and_goats.csv')

# %%
##20. . (A) Using Pandas, make your own .CSV file with data on vegetables and save it. (B) Using Pandas, make a change to your CSV file, and save a copy with a different name.
import pandas as pd
vegetable_data = {
    'Vegetable': ['Carrot', 'Broccoli', 'Spinach', 'Potato'],
    'Quantity': [10, 5, 8, 12],
    'Unit': ['kg', 'kg', 'kg', 'kg']
}
vegetable_df = pd.DataFrame(vegetable_data)
vegetable_df.to_csv('vegetables.csv', index=False)
vegetable_df.loc[vegetable_df['Vegetable'] == 'Carrot', 'Quantity'] = 15
vegetable_df.to_csv('vegetables_updated.csv', index=False)
