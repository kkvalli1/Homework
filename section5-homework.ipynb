# %%
#### What does Pandas stand for?
##### Pandas stands for "Panel Data," which refers to multi-dimensional data sets. It is a powerful open-source data analysis and manipulation library for Python.

##### What are the 2 collections used in Pandas?
##### The two main collections used in Pandas are Series and DataFrame. A Series is a one-dimensional labeled array, while a DataFrame is a two-dimensional labeled data structure with columns of potentially different types.
##### Name 4 things Pandas can do for us.
##### 1. Data Manipulation: Pandas provides tools for cleaning, transforming, and reshaping data.
##### To permanently sort a DataFrame, which ##### keyword should one use with the df.sort() method?
##### The keyword to permanently sort a DataFrame using the df.sort() method is "inplace=True".
##### What is a CSV?
##### CSV stands for "Comma-Separated Values." It is a simple file format used to store tabular data, such as a spreadsheet or database, in plain text where each line represents a data record and each record consists of fields separated by commas.

##### When cleaning data what values do we not like in our data?
##### When cleaning data, we typically do not like missing values (NaN), duplicate entries, outliers, and inconsistent data formats, as they can lead to inaccurate analysis and results.

# %% [markdown]
# ##### What does Pandas stand for?
#
# ##### What are the 2 collections used in Pandas?
# ##### Name 4 things Pandas can do for us.
# ##### To permanently sort a DataFrame, which ##### keyword should one use with the df.sort() method?
# ##### What is a CSV?
# ##### When cleaning data what values do we not like in our data?
