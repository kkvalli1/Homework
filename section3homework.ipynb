# %%
##### 6. Write a multi-line string with your name, favorite food, and dream job on 3 different lines
info = '''Valli Krishna
Pizza
Software Engineer'''
print(info)

## 7. Assign 5 different data types to 5 different variables. At least one datatype must be a string  
# - Print the length of your string
#   - Print the index value of the 4th character in your string
name = "Valli"          # string
age = 30                # integer
height = 5.7            # float
is_student = False      # boolean
hobbies = ["reading", "cycling"]  # list
print(len(name))   
print(name[3])  
## 8. Create a new variable called savvy, and assign it the string with this phrase "Learning Data Analytics and Python is Awesome!"
## - Return a range of characters that slices the above string from the beginning of  "ing" up to before "and"
##  - Replace "Awesome" with "great" in the string
##  - Test and print the savvy string to see it contains "Python"

     
savvy = "Learning Data Analytics and Python is Awesome!"

###### Slice the string from "ing" up to before "and"
###### "ing" starts at index 5, "and" starts at index 20
slice_str = savvy[5:20]
print(slice_str) 

###### Replace "Awesome" with "great"
savvy_replaced = savvy.replace("Awesome", "great")
print(savvy_replaced) 

###### Test if "Python" is in the string and print result
contains_python = "Python" 
print(contains_python)

##### 9. Create and assign 3 more variables called name, age and length using the multi-variable  naming method
   ###### Format a new string called 'miniBio' using variables in curly brackets to complete this phrase... "Hi my name is (name), I am (tall) and (so) old today."
#    - Print 'miniBio'
#   - Cast and print the age variable to a float

# Create multiple variables in snake_case
name, age, length = "Valli", 30, 5.1

# Format string using curly braces for variables
miniBio = f"Hi my name is {name}, I am {length} feet and {age} years old today."

# Print the miniBio string
print(miniBio)  

# Cast age to float and print
age_float = float(age)
print("Age in float" ,age_float)  

#### Complex Data Types:


# 10. Create a list of at least 5 elements of mixed data types
#  - Replace a part of it with something else
#   - Append or insert several more items to the list
#   - Find and print the length of the list
#   - Slice a sub-section of the 1st list, and save it to a different 2nd list
#   - Print the 2nd list
#   - Extend your original list with the 2nd list sliced above
#   - Create a new list called "simList" containing at least 5 elements of the same data type, either string, integer, float, or Boolean
#   - Sort "simList", and print the list
#   - Copy the "simList" list to another 3rd list
#   - Add the 2nd and 3rd lists together into a 4th list





###### Create a mixed data type list with at least 5 elements
mixed_list = [10, "apple", 3.14, True, None]

###### Replace the second element ("apple") with "orange"
mixed_list[1] = "orange"

###### Append and insert several more items
mixed_list.append(False)
mixed_list.insert(2, 42)
mixed_list.extend(["banana", 7])

###### Find and print the length of the list
print(len(mixed_list)) 

###### Slice a sub-section and save it to a different list
second_list = mixed_list[2:5]

###### Print the second list
print(second_list)  

###### Extend original list with the sliced second list
mixed_list.extend(second_list)

###### Create a new list with same data type elements (all integers)
simList = [7, 3, 14, 1, 9]

###### Sort simList and print it
simList.sort()
print(simList)  

#### Copy simList to another list
third_list = simList.copy()

#### Add (concatenate) second_list and third_list into a fourth list
fourth_list = second_list + third_list

#### Print the fourth list
print(fourth_list)  


#11. Create a tuple of about 5 elements
#   - Multiply your tuple by 3 and save it to a new 2nd tuple
#   - Access and print the 12th element from the 2nd tuple
#   - Sort the 2nd tuple and print it
#   - Copy 4 specific elements from your 2nd tuple to a new 3nd tuple
#   - Unpack the 3rd tuple into 4 variables and print these variables
#   - Create a 4th tuple with single item 50 and print this tuple
#   - Add the 2nd and 3rd tuple together into a 5th tuple and print the tuple



##### Create a tuple of about 5 elements
tuple1 = (10, 20, 30, 40, 50)

###### Multiply the tuple by 3 and save it to a new tuple
tuple2 = tuple1 * 3

###### Access and print the 12th element  from tuple2
print(tuple2[11]) 

###### Sort the tuple2 and print it 
sorted_tuple2 = tuple(sorted(tuple2))
print(sorted_tuple2)

###### Copy 4 specific elements from tuple2 to a new tuple 
tuple3 = tuple2[5:9]

###### Unpack tuple3 into 4 variables and print them
a, b, c, d = tuple3
print(a, b, c, d)

###### Create a single-item tuple with 50 and print it 
tuple4 = (50,)
print(tuple4)

###### Add (concatenate) tuple2 and tuple3 into a 5th tuple and print it
tuple5 = tuple2 + tuple3
print(tuple5)

#12. Create a set of about 3 elements
#   - Add a list of fruits to the above set and print the result
#  - Add a car element to your set
#  - Create a 2nd set with a few odd items
#  - Save the union of 1st set and 2nd set to a 3rd set
#  - Pop an element from the 2nd set, and print the remainder of the set
#  - Clear the 1st set and print the result
#  - Discard an element, and remove another element from the 3rd set
#  - Print the remainder of the 3rd set

    #### Create a set of about 3 elements
set1 = {"apple", 42, True}

# d a list of fruits to the above set and print the result
fruits = ["banana", "cherry", "date"]
set1.update(fruits)
print(set1)  

#### Add a car element to your set
set1.add("car")
print(set1)  

#### Create a 2nd set with odd items
set2 = {3, "dog", False, 42}

#### Save the union of 1st and 2nd set to a 3rd set
set3 = set1.union(set2)
print(set3)

###### Pop an element from the 2nd set and print remainder
popped_item = set2.pop()
print("Popped:", popped_item)
print("Remaining set2:", set2)

###### Clear the 1st set and print result
set1.clear()
print("Cleared set1:", set1)

###### Discard an element and remove another from 3rd set
set3.discard("banana") 
set3.remove("dog")     
print("Set3 after discard and remove:", set3)



# 13. Create a dictionary with at least 5 values of different data types
#   - Print out 1 value
#  - Replace any one value in your dictionary with your name
#   - Add your favorite color to the dictionary
#   - Add a list, tuple or set to your dictionary
#    - Print a list of the dictionary keys
# 3   - Print a list of the dictionary values
#  - Copy your 1st dictionary into a 2nd dictionary
#   - Pop an item from the 2nd dictionary, and print the dictionary
#   - Remove all the elements from the 2nd dictionary and print the result
###### Create a dictionary with at least 5 values of different data types
mydict = {
    "number": 42,
    "fruit": "apple",
    "price": 3.14,
    "is_available": True,
    "info": {"color": "red", "size": "medium"}
}

###### Print out one value
print(mydict["fruit"])  

###### Replace a value in dictionary with a name
mydict["fruit"] = "Alice"

###### Add your favorite color to the dictionary
mydict["favorite_color"] = "blue"

###### Add a list to the dictionary
mydict["hobbies"] = ["reading", "cycling"]

###### Print a list of dictionary keys
print(list(mydict.keys()))

###### Print a list of dictionary values
print(list(mydict.values()))

###### Copy the first dictionary into a second dictionary
dict2 = mydict.copy()

###### Pop an item from the second dictionary (remove "price") and print the dictionary
dict2.pop("price")
print(dict2)

###### Remove all elements from the second dictionary and print the result
dict2.clear()
print(dict2)
# Out:
# Valli Krishna
# Pizza
# Software Engineer
# 5
# l
# ing Data Analyt
# Learning Data Analytics and Python is great!
# Python
# Hi my name is Valli, I am 5.1 feet and 30 years old today.
# Age in float 30.0
# 9
# [42, 3.14, True]
# [1, 3, 7, 9, 14]
# [42, 3.14, True, 1, 3, 7, 9, 14]
# 20
# (10, 10, 10, 20, 20, 20, 30, 30, 30, 40, 40, 40, 50, 50, 50)
# 10 20 30 40
# (50,)
# (10, 20, 30, 40, 50, 10, 20, 30, 40, 50, 10, 20, 30, 40, 50, 10, 20, 30, 40)
# {True, 42, 'date', 'apple', 'cherry', 'banana'}
# {True, 42, 'date', 'apple', 'cherry', 'banana', 'car'}
# {False, True, 3, 'dog', 42, 'date', 'apple', 'cherry', 'banana', 'car'}
# Popped: dog
# Remaining set2: {False, 42, 3}
# Cleared set1: set()
# Set3 after discard and remove: {False, True, 3, 42, 'date', 'apple', 'cherry', 'car'}
# apple
# ['number', 'fruit', 'price', 'is_available', 'info', 'favorite_color', 'hobbies']
# [42, 'Alice', 3.14, True, {'color': 'red', 'size': 'medium'}, 'blue', ['reading', 'cycling']]
# ...

# %% [markdown]
# #### Data Types:
#
# <ins>Use markdown formatting for the following questions (e.g., bold lettering, bullet points, different font sizes, etc.)</ins>:
#
# ### 1. What is an algorithm?
#  #### Algorithm is a set of step-by-step instructions  to solve a problem or accomplish a specific task. They take inputs, perform a sequence of operations, and produce outputs.
# ### 2. Variable names may not start with certain characters - name two.
#  #### variable names cannot begin with characters like "1" or "9". Special characters — such as hyphens (-), spaces, or symbols like @, !, $, etc
# ### 3. What is a Semantic error?
# #### A semantic error in programming occurs when the code is syntactically correct—that is, it follows all language rules and can run without causing a error but the logic behind the code is flawed.
# ### 4. What is the #1 rule of coding / debugging?
#  ####
#
# ### 5. List 5 Python reserved words.
# #### Five Python reserved words are:
#
# if
#
# else
#
# while
#
# def
#
# return
#
#
# <br>

# %%
##### 6. Write a multi-line string with your name, favorite food, and dream job on 3 different lines
info = '''Valli Krishna
Pizza
Software Engineer'''
print(info)

# 7. Assign 5 different data types to 5 different variables. At least one datatype must be a string  
#    - Print the length of your string
#    - Print the index value of the 4th character in your string
name = "Valli"          # string
age = 30                # integer
height = 5.7            # float
is_student = False      # boolean
hobbies = ["reading", "cycling"]  # list
print(len(name))   
print(name[3])  
# 8. Create a new variable called savvy, and assign it the string with this phrase "Learning Data Analytics and Python is Awesome!"
#    - Return a range of characters that slices the above string from the beginning of  "ing" up to before "and"
#   - Replace "Awesome" with "great" in the string
#   - Test and print the savvy string to see it contains "Python"

     
savvy = "Learning Data Analytics and Python is Awesome!"

###### Slice the string from "ing" up to before "and"
###### "ing" starts at index 5, "and" starts at index 20
slice_str = savvy[5:20]
print(slice_str) 

###### Replace "Awesome" with "great"
savvy_replaced = savvy.replace("Awesome", "great")
print(savvy_replaced) 

###### Test if "Python" is in the string and print result
contains_python = "Python" 
print(contains_python)

##### 9. Create and assign 3 more variables called name, age and length using the multi-variable  naming method
   ###### Format a new string called 'miniBio' using variables in curly brackets to complete this phrase... "Hi my name is (name), I am (tall) and (so) old today."
#    - Print 'miniBio'
#   - Cast and print the age variable to a float

# Create multiple variables in snake_case
name, age, length = "Valli", 30, 5.1

# Format string using curly braces for variables
miniBio = f"Hi my name is {name}, I am {length} feet and {age} years old today."

# Print the miniBio string
print(miniBio)  

# Cast age to float and print
age_float = float(age)
print("Age in float" ,age_float)  


#### Complex Data Types:



# 10. Create a list of at least 5 elements of mixed data types
#  - Replace a part of it with something else
#   - Append or insert several more items to the list
#   - Find and print the length of the list
#    - Slice a sub-section of the 1st list, and save it to a different 2nd list
#   - Print the 2nd list
 #   - Extend your original list with the 2nd list sliced above
#  - Create a new list called "simList" containing at least 5 elements of the same data type, either string, integer, float, or Boolean
 #   - Sort "simList", and print the list
#   - Copy the "simList" list to another 3rd list
#   - Add the 2nd and 3rd lists together into a 4th list





###### Create a mixed data type list with at least 5 elements
mixed_list = [10, "apple", 3.14, True, None]

###### Replace the second element ("apple") with "orange"
mixed_list[1] = "orange"

###### Append and insert several more items
mixed_list.append(False)
mixed_list.insert(2, 42)
mixed_list.extend(["banana", 7])

###### Find and print the length of the list
print(len(mixed_list)) 

###### Slice a sub-section and save it to a different list
second_list = mixed_list[2:5]

###### Print the second list
print(second_list)  

###### Extend original list with the sliced second list
mixed_list.extend(second_list)

###### Create a new list with same data type elements (all integers)
simList = [7, 3, 14, 1, 9]

###### Sort simList and print it
simList.sort()
print(simList)  

#### Copy simList to another list
third_list = simList.copy()

#### Add (concatenate) second_list and third_list into a fourth list
fourth_list = second_list + third_list

#### Print the fourth list
print(fourth_list)  


#11. Create a tuple of about 5 elements
#   - Multiply your tuple by 3 and save it to a new 2nd tuple
#   - Access and print the 12th element from the 2nd tuple
#   - Sort the 2nd tuple and print it
#   - Copy 4 specific elements from your 2nd tuple to a new 3nd tuple
#   - Unpack the 3rd tuple into 4 variables and print these variables
#   - Create a 4th tuple with single item 50 and print this tuple
#   - Add the 2nd and 3rd tuple together into a 5th tuple and print the tuple



##### Create a tuple of about 5 elements
tuple1 = (10, 20, 30, 40, 50)

###### Multiply the tuple by 3 and save it to a new tuple
tuple2 = tuple1 * 3

###### Access and print the 12th element  from tuple2
print(tuple2[11]) 

###### Sort the tuple2 and print it 
sorted_tuple2 = tuple(sorted(tuple2))
print(sorted_tuple2)

###### Copy 4 specific elements from tuple2 to a new tuple 
tuple3 = tuple2[5:9]

###### Unpack tuple3 into 4 variables and print them
a, b, c, d = tuple3
print(a, b, c, d)

###### Create a single-item tuple with 50 and print it 
tuple4 = (50,)
print(tuple4)

###### Add (concatenate) tuple2 and tuple3 into a 5th tuple and print it
tuple5 = tuple2 + tuple3
print(tuple5)

#12. Create a set of about 3 elements
#    - Add a list of fruits to the above set and print the result
#    - Add a car element to your set
#   - Create a 2nd set with a few odd items
#   - Save the union of 1st set and 2nd set to a 3rd set
#   - Pop an element from the 2nd set, and print the remainder of the set
#   - Clear the 1st set and print the result
#   - Discard an element, and remove another element from the 3rd set
#   - Print the remainder of the 3rd set

    #### Create a set of about 3 elements
set1 = {"apple", 42, True}

 #Add a list of fruits to the above set and print the result
fruits = ["banana", "cherry", "date"]
set1.update(fruits)
print(set1)  

#### Add a car element to your set
set1.add("car")
print(set1)  

### Create a 2nd set with odd items
set2 = {3, "dog", False, 42}

#### Save the union of 1st and 2nd set to a 3rd set
set3 = set1.union(set2)
print(set3)

###### Pop an element from the 2nd set and print remainder
##### popped_item = set2.pop()
##### print("Popped:", popped_item)
##### print("Remaining set2:", set2)

###### Clear the 1st set and print result
##### set1.clear()
##### print("Cleared set1:", set1)

###### Discard an element and remove another from 3rd set
set3.discard("banana") 
set3.remove("dog")     
print("Set3 after discard and remove:", set3)



# 13. Create a dictionary with at least 5 values of different data types
# - Print out 1 value
#  - Replace any one value in your dictionary with your name
# - Add your favorite color to the dictionary
#  - Add a list, tuple or set to your dictionary
#  - Print a list of the dictionary keys
#  - Print a list of the dictionary values
#  - Copy your 1st dictionary into a 2nd dictionary
#  - Pop an item from the 2nd dictionary, and print the dictionary
#  - Remove all the elements from the 2nd dictionary and print the result
###### Create a dictionary with at least 5 values of different data types
mydict = {
    "number": 42,
    "fruit": "apple",
    "price": 3.14,
    "is_available": True,
    "info": {"color": "red", "size": "medium"}
}

###### Print out one value
print(mydict["fruit"])  

###### Replace a value in dictionary with a name
mydict["fruit"] = "Alice"

###### Add your favorite color to the dictionary
mydict["favorite_color"] = "blue"

###### Add a list to the dictionary
mydict["hobbies"] = ["reading", "cycling"]

###### Print a list of dictionary keys
print(list(mydict.keys()))

###### Print a list of dictionary values
print(list(mydict.values()))

###### Copy the first dictionary into a second dictionary
dict2 = mydict.copy()

###### Pop an item from the second dictionary (remove "price") and print the dictionary
dict2.pop("price")
print(dict2)

###### Remove all elements from the second dictionary and print the result
dict2.clear()
print(dict2)
# Out:
# Valli Krishna
# Pizza
# Software Engineer
# 5
# l
# ing Data Analyt
# Learning Data Analytics and Python is great!
# Python
# Hi my name is Valli, I am 5.1 feet and 30 years old today.
# Age in float 30.0
# 9
# [42, 3.14, True]
# [1, 3, 7, 9, 14]
# [42, 3.14, True, 1, 3, 7, 9, 14]
# 20
# (10, 10, 10, 20, 20, 20, 30, 30, 30, 40, 40, 40, 50, 50, 50)
# 10 20 30 40
# (50,)
# (10, 20, 30, 40, 50, 10, 20, 30, 40, 50, 10, 20, 30, 40, 50, 10, 20, 30, 40)
# {True, 42, 'date', 'apple', 'cherry', 'banana'}
# {True, 42, 'date', 'apple', 'cherry', 'banana', 'car'}
# {False, True, 3, 'dog', 42, 'date', 'apple', 'cherry', 'banana', 'car'}
# Set3 after discard and remove: {False, True, 3, 42, 'date', 'apple', 'cherry', 'car'}
# apple
# ['number', 'fruit', 'price', 'is_available', 'info', 'favorite_color', 'hobbies']
# [42, 'Alice', 3.14, True, {'color': 'red', 'size': 'medium'}, 'blue', ['reading', 'cycling']]
# ...
